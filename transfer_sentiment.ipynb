# %%
import mysql.connector as connector
import psycopg2

# %%
conn = connector.connect(host='localhost', user='root', password='123456', database='my_db')
mycursor= conn.cursor()
mycursor.execute('SELECT * FROM price_sentiment')
d_table = mycursor.fetchall()

# %%
conn_pg = psycopg2.connect('postgresql://stock_price_g9q6_user:NxjC5lOyzg5HJftmjj49JUpYxLquARBl@dpg-d59ul99r0fns7381saug-a.singapore-postgres.render.com/stock_price_g9q6')
conn_pg.autocommit = True    
pg_cursor = conn_pg.cursor()     
pg_cursor.execute("select * from price_sentiment")  
d_table_pg = pg_cursor.fetchall()

# %%
d_table_pg

# %%
for i in range(len(d_table)):
    date_time = d_table[i][0]
    if date_time not in [d_table_pg[j][0] for j in range(len(d_table_pg))]:
        insert_query = "INSERT INTO  price_sentiment (Date, Open, High, Low, Close, Volume, Dividends, Stock_Splits, Score,	Positive,	Negative,	Neutral,	Total_Sentiment) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        pg_cursor.execute(insert_query, d_table[i])
        print(f"Inserted record for date: {date_time}")
