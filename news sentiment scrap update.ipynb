# %%
from bs4 import BeautifulSoup
import lxml
import requests
import time
import random
import pandas as pd
from datetime import datetime
import psycopg2
#import mysql.connector as connector

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://www.google.com/"
}

url = 'https://markets.businessinsider.com/news/nvda-stock?p=1'

# %%
#soup = BeautifulSoup(page.text, 'lxml')
#articles = soup.find_all('div', class_ ='latest-news__story')

# %%
conn = psycopg2.connect('postgresql://stock_price_78jd_user:RJtAfdorSK6ZmDiE43EocRK9JOxGn57M@dpg-d4lrugjuibrs7387h89g-a.singapore-postgres.render.com/stock_price_78jd')
conn.autocommit = True
mycursor = conn.cursor()
mycursor.execute('Select * From price_sentiment')
sentiment = mycursor.fetchall()

df_sentiment = pd.DataFrame(sentiment, columns=['Date', 'Open',	'High',	'Low',	'Close',	'Volume',	'Dividends',	'Stock Splits', 'Score',
                                                'Positive', 'Negative', 'Neutral', 'Total_Sentiment'])

df_sentiment_date = df_sentiment['Date']

df_sentiment.set_index('Date', drop=True)

df_sentiment.drop_duplicates(inplace=True)

df_sentiment.sort_index(inplace=True)

# %%
# # try:
# conn = connector.connect(user='root', password='123456', host='localhost', port='3306', database='my_db')
# # except connector.Error as er:
# #     print('Error code:', er.errorno)
# #     print('Error msg:', er.msg)

# mycursor = conn.cursor()

# mycursor.execute('SELECT * FROM price_sentiment')
# sentiment =  mycursor.fetchall()

# df_sentiment = pd.DataFrame(sentiment, columns=['Date', 'Open',	'High',	'Low',	'Close',	'Volume',	'Dividends',	'Stock Splits', 'Score',
#                                                 'Positive', 'Negative', 'Neutral', 'Total_Sentiment'])

# df_sentiment_date = df_sentiment['Date']

# df_sentiment.set_index('Date', drop=True)

# df_sentiment.drop_duplicates(inplace=True)

# %%
last_date = df_sentiment_date.iloc[-1]

# %%
print(last_date)
# Out:
# 2025-12-26

# %%
data = []
page_number = 1
#today = datetime.today().strftime('%Y-%m-%d')
article_date = '1999-01-01'

while article_date != last_date:
    try:
        url = f'https://markets.businessinsider.com/news/nvda-stock?p={page_number}'

        page = requests.get(url, headers = headers)  

        time.sleep(random.uniform(3, 8))  

        soup = BeautifulSoup(page.text, 'lxml')
        articles = soup.find_all('div', class_ ='latest-news__story')

        if not articles:
            # Break the loop if no articles are found on the current page
            break

        for row in articles:
            date_time = row.find('time', class_= 'latest-news__date').get('datetime')
            article_dt = datetime.strptime(date_time, "%m/%d/%Y %I:%M:%S %p")
            article_date = article_dt.date()
            if article_date == last_date:
                break
            title = row.find('a', class_= 'news-link').text
            source = row.find('span', class_= 'latest-news__source').text
            link = row.find('a',class_= 'news-link').get('href')

              # Extract only the date part (YYYY-MM-DD)

            ## To scrape the article for a day and not the whole news pages
            #if article_date != today:
                #break  # Stop scraping if the article is from a previous day

            data.append([article_date,title,source,link])
            print(article_date, 'is added')
        
        page_number +=1
    
    except Exception as e:
        print(e)
        break



df = pd.DataFrame(data, columns = [ 'DateTime', 'Title', 'Source', 'Link'])
print('Done')

#df.to_csv('source_new.csv', index=False)
# Out:
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-29 is added
# 2025-12-28 is added
# 2025-12-28 is added
# 2025-12-28 is added
# 2025-12-28 is added
# 2025-12-28 is added
# 2025-12-28 is added
# 2025-12-28 is added
# 2025-12-27 is added
# 2025-12-27 is added
# 2025-12-27 is added
# 2025-12-27 is added
# Done

# %%
# #to scrape data from a single page only

# data = []

# page_number = 1

# url = f'https://markets.businessinsider.com/news/nvda-stock?p={page_number}'

# page = requests.get(url, headers = headers)  

# time.sleep(random.uniform(3, 8))  

# soup = BeautifulSoup(page.text, 'lxml')
# articles = soup.find_all('div', class_ ='latest-news__story')

# for row in articles:
#     datetime = row.find('time', class_= 'latest-news__date').get('datetime')
#     title = row.find('a', class_= 'news-link').text
#     source = row.find('span', class_= 'latest-news__source').text
#     link = row.find('a',class_= 'news-link').get('href')

#              #article_date = datetime.split('T')[0]  # Extract only the date part (YYYY-MM-DD)

#              ## To scrape the article for a day and not the whole news pages
#             #if article_date != today:
#                 #break  # Stop scraping if the article is from a previous day

#     data.append([datetime,title,source,link])

# df = pd.DataFrame(data, columns = [ 'DateTime', 'Title', 'Source', 'Link'])

# %%
df
# Out:
#       DateTime                                              Title  \
# 0   2025-12-29  AI Daily: SoftBank Group to acquire DigitalBri...
# 1   2025-12-29  New Buy Rating for Nvidia (NVDA), the Technolo...
# 2   2025-12-29  Morning News Wrap-Up: Monday’s Biggest Stock M...
# 3   2025-12-29  AMD & Nvidia (NVDA) Stocks Slip on 2026 GPU Pr...
# 4   2025-12-29  3 Best ETFs to Invest In, According to AI Anal...
# 5   2025-12-29  Nvidia completes $5B purchase of shares from I...
# 6   2025-12-29  3 ‘Strong Buy’ Stocks to Buy Today,12/29/2025,...
# 7   2025-12-29    Notable open interest changes for December 29th
# 8   2025-12-29  Morning Movers: DigitalBridge jumps following ...
# 9   2025-12-29  Video: DigitalBridge jumps as SoftBank said to...
# 10  2025-12-29  Nvidia (NVDA) Becomes a Top Intel (INTC) Share...
# 11  2025-12-29  Vanguard Total Stock Market ETF (VTI) Daily Up...
# 12  2025-12-29           Intel completes $5B stock sale to Nvidia
# 13  2025-12-29  5 Major Quantum Computing Breakthroughs that S...
# 14  2025-12-29  ‘It’s a Clear Leader,’ Says Top Analysts About...
# 15  2025-12-29  War Chest for a Bubble Burst? AI Startups Rais...
# 16  2025-12-29  Nvidia (NVDA) Receives a Rating Update from a ...
# 17  2025-12-29  Nvidia deal with Groq fortifies competitive po...
# 18  2025-12-29     UBS remains bullish on Nvidia shares into 2026
# 19  2025-12-29  Nvidia deal with Groq could extend AI infrastr...
# 20  2025-12-29  Nvidia deal with Groq a ‘clear positive,’ says...
# 21  2025-12-29  New Buy Rating for Nvidia (NVDA), the Technolo...
# 22  2025-12-29  3 ‘Strong Buy’ Quantum Computing Stocks to Buy...
# 23  2025-12-28  Silver is now the third most valuable asset in...
# 24  2025-12-28  BofA Identifies 6 Behind-the-Scenes AI Stocks ...
# 25  2025-12-28  Silver Could Soon Overtake Nvidia (NVDA) in Ma...
# 26  2025-12-28  Why Alibaba (BABA) Could Lead the AI Market in...
# 27  2025-12-28  The Week That Was, The Week Ahead: Macro & Mar...
# 28  2025-12-28  NVDA vs. SOUN: Which AI Stock Is the Best Buy ...
# 29  2025-12-28  3 ‘Strong Buy’ Quantum Computing Stocks to Buy...
# 30  2025-12-27  Wall Street Sees Strong Upside for Broadcom St...
# 31  2025-12-27  Nvidia’s “Base Case” Is $250 by End of 2026, S...
# 32  2025-12-27  Nvidia’s Latest AI Deal Gets a Nod from Wall S...
# 33  2025-12-27  Intel Stock Is Up 80%+ YTD, But Wall Street Re...
#
#            Source                                               Link
# 0        TipRanks  /news/stocks/ai-daily-softbank-group-to-acquir...
# 1        TipRanks  /news/stocks/new-buy-rating-for-nvidia-nvda-th...
# 2        TipRanks  /news/stocks/morning-news-wrap-up-monday-s-big...
# 3        TipRanks  /news/stocks/amd-nvidia-nvda-stocks-slip-on-20...
# 4        TipRanks  /news/stocks/3-best-etfs-to-invest-in-accordin...
# 5   Seeking Alpha  https://seekingalpha.com/news/4535683-nvidia-c...
# 6        TipRanks  /news/stocks/3-strong-buy-stocks-to-buy-today-...
# 7        TipRanks  /news/stocks/notable-open-interest-changes-for...
# 8        TipRanks  /news/stocks/morning-movers-digitalbridge-jump...
# 9        TipRanks  /news/stocks/video-digitalbridge-jumps-as-soft...
# 10       TipRanks  /news/stocks/nvidia-nvda-becomes-a-top-intel-i...
# 11       TipRanks  /news/stocks/vanguard-total-stock-market-etf-v...
# 12       TipRanks  /news/stocks/intel-completes-5b-stock-sale-to-...
# 13       TipRanks  /news/stocks/5-major-quantum-computing-breakth...
# 14       TipRanks  /news/stocks/it-s-a-clear-leader-says-top-anal...
# 15       TipRanks  /news/stocks/war-chest-for-a-bubble-burst-ai-s...
# 16       TipRanks  /news/stocks/nvidia-nvda-receives-a-rating-upd...
# 17       TipRanks  /news/stocks/nvidia-deal-with-groq-fortifies-c...
# 18       TipRanks  /news/stocks/ubs-remains-bullish-on-nvidia-sha...
# 19       TipRanks  /news/stocks/nvidia-deal-with-groq-could-exten...
# 20       TipRanks  /news/stocks/nvidia-deal-with-groq-a-clear-pos...
# 21       TipRanks  /news/stocks/new-buy-rating-for-nvidia-nvda-th...
# 22       TipRanks  /news/stocks/3-strong-buy-quantum-computing-st...
# 23  Seeking Alpha  https://seekingalpha.com/news/4535586-silver-i...
# 24       TipRanks  /news/stocks/bofa-identifies-6-behind-the-scen...
# 25       TipRanks  /news/stocks/silver-could-soon-overtake-nvidia...
# 26       TipRanks  /news/stocks/why-alibaba-baba-could-lead-the-a...
# 27       TipRanks  /news/stocks/the-week-that-was-the-week-ahead-...
# 28       TipRanks  /news/stocks/nvda-vs-soun-which-ai-stock-is-th...
# 29       TipRanks  /news/stocks/3-strong-buy-quantum-computing-st...
# 30       TipRanks  /news/stocks/wall-street-sees-strong-upside-fo...
# 31       TipRanks  /news/stocks/nvidia-s-base-case-is-250-by-end-...
# 32       TipRanks  /news/stocks/nvidia-s-latest-ai-deal-gets-a-no...
# 33       TipRanks  /news/stocks/intel-stock-is-up-80-ytd-but-wall...

# %%
#df= pd.read_csv("source.csv")

# %%
import torch
from transformers import pipeline


pipe = pipeline("text-classification", model="ProsusAI/finbert", framework="pt")
# Out:
# Device set to use cpu

# %%
def sentiment_analysis(text):
    data = pipe(text)
    return data

# %%
text = df[df['DateTime'] > last_date]['Title']

sentiment = []

for i in text:
        sentiment.append(sentiment_analysis(str(i)))

labels = [res[0]['label'] for res in sentiment]
scores = [res[0]['score'] for res in sentiment]

df['Label'] = labels
df['Score'] = scores

# %%
def sentiment_score(label):
    if label == 'positive':
        return 1
    if label == 'neutral':
        return 0
    if label == 'negative':
        return -1

# %%
df['Label'] = df['Label'].apply(sentiment_score)

# %%
#df.to_csv('sentiment_score.csv', index = False)

# %%
# import pandas as pd 

#df = pd.read_csv('sentiment_score.csv')
# df.drop('Unnamed: 0', axis= 1, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['DateTime'])
df['Date'] = df['Date'].dt.date

df = df.set_index('Date')
df.sort_index()
df.drop('DateTime',inplace=True,axis=1)

# %%
def count_positive(value):

    if value == 1:
        return 1
    else:
        return 0

def count_neg(value):

    if value == -1:
        return 1
    else:
        return 0

def count_neu(value):

    if value == 0:
        return 1
    else:
        return 0

# %%
df['Positive'] = df['Label'].apply(count_positive)
df['Negative'] = df['Label'].apply(count_neg)
df['Neutral'] = df['Label'].apply(count_neu)

# %%
df_score = df.groupby(df.index).agg({
    'Score': 'mean',
    'Positive': 'sum',
    'Negative': 'sum',
    'Neutral': 'sum'
})

# %%
df_score['Total_Sentiment'] = df_score.apply(lambda row: row['Positive'] - row['Negative']/(row['Positive'] + row['Negative'] + row['Neutral']), axis=1)

# %%
df_score.tail()
# Out:
#                Score  Positive  Negative  Neutral  Total_Sentiment
# Date
# 2025-12-27  0.742604         3         0        1         3.000000
# 2025-12-28  0.863854         2         0        5         2.000000
# 2025-12-29  0.835464        10         1       12         9.956522

# %%
df_score.drop_duplicates(inplace=True)

# %%
mycursor2 = conn.cursor()

mycursor2.execute('SELECT * FROM stock_price')
price =  mycursor2.fetchall()

df_price = pd.DataFrame(price, columns=['Date', 'Open',	'High',	'Low',	'Close',	'Volume',	'Dividends',	'Stock Splits'])

df_price_date = df_price['Date']

df_price.set_index('Date', drop=True)

df_price.drop_duplicates(inplace=True)

# %%
df_merge = df_price.merge(df_score, on = 'Date')

df_merge.set_index('Date', drop=True, inplace=True)

df_merge.to_csv('test.csv')

df_merge = df_merge[~df_merge.index.duplicated()]

# %%
# mycursor.execute("SHOW TABLES")

# tables = [table[0] for table in mycursor.fetchall()]

# if 'price_sentiment' not in tables:
#     mycursor.execute("CREATE TABLE price_sentiment (Date DATE UNIQUE, Open FLOAT(24), High FLOAT(24), Low FLOAT(24), Close FLOAT(24), Volume FLOAT(24), Dividends FLOAT(24), Stock_Splits FLOAT(24), Score FLOAT(24), Positive	INT, Negative INT,	Neutral INT, 	Total_Sentiment FLOAT(24))")
#     print("Table 'stock_price' created successfully.")
# else:
#     print("Table 'stock_price' already exists.")

# %%
sql = "INSERT INTO  price_sentiment (Date, Open, High, Low, Close, Volume, Dividends, Stock_Splits, Score,	Positive,	Negative,	Neutral,	Total_Sentiment) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)" \
"ON CONFLICT (Date) DO NOTHING"

# %%
tuples_list = list(df_merge.itertuples(index=True, name=None))

# %%
mycursor.executemany(sql, tuples_list)

# %%
conn.commit()

mycursor.close()
conn.close()
